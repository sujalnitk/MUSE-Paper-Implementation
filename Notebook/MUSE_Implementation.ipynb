# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import kagglehub
from torch.utils.data import Dataset , DataLoader
import os
torch.manual_seed(42)

# %%
device = torch.device('cuda')

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sujalkumarsahni/fasttext-embeddings")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/sujalkumarsahni/fasttext-embeddings/versions/1

# %%
en_emb_np = np.load("/root/.cache/kagglehub/datasets/sujalkumarsahni/fasttext-embeddings/versions/1/en_emb_fasttext.npy" , allow_pickle = True).item()

# %%
hi_emb_np = np.load("/root/.cache/kagglehub/datasets/sujalkumarsahni/fasttext-embeddings/versions/1/hi_emb_fasttext.npy" , allow_pickle=True).item()

# %%
en_words = []
en_emb = []
for i in en_emb_np:
  en_words.append(i)
  en_emb.append(en_emb_np[i])

en_words = en_words[:50000]

# %%
hi_words = []
hi_emb = []
for i in hi_emb_np:
  hi_words.append(i)
  hi_emb.append(hi_emb_np[i])

hi_words = hi_words[:50000]

# %%
en_emb = torch.tensor(en_emb[:50000] , dtype=torch.float32 , device = device)
hi_emb = torch.tensor(hi_emb[:50000] , dtype = torch.float32 , device = device)

# Normalize embeddings
en_emb = en_emb / torch.norm(en_emb, dim=1, keepdim=True)
hi_emb = hi_emb / torch.norm(hi_emb, dim=1, keepdim=True)
# Out:
# <ipython-input-9-d61374a05e3c>:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   en_emb = torch.tensor(en_emb[:50000] , dtype=torch.float32 , device = device)

# %%
class Discriminator(nn.Module):

  def __init__(self , input_dim):
    super().__init__()
    self.model = nn.Sequential(
        nn.Linear(input_dim , 2048),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.4),
        nn.Linear(2048 , 1),
        nn.Sigmoid()
    )

  def forward(self , x):
    return self.model(x)

# %%
W = nn.Parameter(torch.randn(300,300 , device=device) )

# %%
W
# Out:
# Parameter containing:
# tensor([[ 0.1940,  2.1614, -0.1721,  ..., -0.5308, -1.7914, -0.2863],
#         [ 0.0805, -1.3001,  1.3404,  ...,  0.3699,  0.7433, -0.1199],
#         [-0.9188,  1.3789,  0.0839,  ...,  0.3610, -0.9032, -0.3624],
#         ...,
#         [ 0.3048,  0.0817,  0.1234,  ..., -0.7819, -1.9529, -0.5169],
#         [-1.6966, -1.3123,  0.8327,  ...,  0.1246,  0.3610,  0.4237],
#         [-0.4136,  0.3002, -1.2926,  ...,  0.3381,  1.1602,  2.1106]],
#        device='cuda:0', requires_grad=True)

# %%
model_d = Discriminator(300)
model_d = model_d.to(device)
learning_rate = 0.1
optimizer_D = optim.SGD(model_d.parameters() , lr = 0.1 )
optimizer_M = optim.SGD([W] , lr = 0.1 )
loss_function = nn.BCELoss()
epochs = 150
beta = 0.01

# %%
# creating  Label
real_label = torch.ones((en_emb.shape[0], 1), device=device)
fake_label = torch.zeros((en_emb.shape[0], 1), device=device)

real_label = real_label - 0.1
fake_label = real_label - 0.9

# %%
for epoch in range(epochs):
    # Discriminator step
    fake_emb = en_emb @ W.detach()

    x = torch.cat([fake_emb , hi_emb] , 0)

    y = torch.FloatTensor(2*fake_emb.shape[0]).zero_()
    y = y.to(device)
    y[:fake_emb.shape[0]] = real_label.squeeze()
    y[fake_emb.shape[0]:] = fake_label.squeeze()
    y = y.view(-1, 1)

    preds = model_d(x)

    total_loss = loss_function(preds , y)
    optimizer_D.zero_grad()
    total_loss.backward()
    optimizer_D.step()

    mapped_emb = en_emb @ W
    src_tgt = torch.cat([mapped_emb , hi_emb] , 0)
    preds_m = model_d(src_tgt)
    loss_m = loss_function(preds_m , 1-y)

    optimizer_M.zero_grad()
    loss_m.backward()
    optimizer_M.step()

    with torch.no_grad():

      W.copy_((1 + beta) * W - beta * W.mm(W.transpose(0, 1).mm(W)))

    print(f'epoch : {epoch+1} , Discriminator loss : {total_loss} , mapper loss : {loss_m} ')
    print('-'*150)
# Out:
# epoch : 1 , Discriminator loss : 0.7063919901847839 , mapper loss : 1.1315871477127075
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 2 , Discriminator loss : 0.5512380003929138 , mapper loss : 1.1834408044815063
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 3 , Discriminator loss : 0.5369592308998108 , mapper loss : 1.2120674848556519
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 4 , Discriminator loss : 0.5240294933319092 , mapper loss : 1.233568787574768
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 5 , Discriminator loss : 0.5119518041610718 , mapper loss : 1.2513948678970337
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 6 , Discriminator loss : 0.5004343390464783 , mapper loss : 1.2690718173980713
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 7 , Discriminator loss : 0.4894677698612213 , mapper loss : 1.2840332984924316
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 8 , Discriminator loss : 0.4789257049560547 , mapper loss : 1.2996068000793457
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 9 , Discriminator loss : 0.4690721035003662 , mapper loss : 1.3150862455368042
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 10 , Discriminator loss : 0.45950382947921753 , mapper loss : 1.3300203084945679
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 11 , Discriminator loss : 0.45049166679382324 , mapper loss : 1.3454458713531494
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 12 , Discriminator loss : 0.4418417811393738 , mapper loss : 1.3612370491027832
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 13 , Discriminator loss : 0.43347033858299255 , mapper loss : 1.3763262033462524
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 14 , Discriminator loss : 0.42557623982429504 , mapper loss : 1.3911885023117065
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 15 , Discriminator loss : 0.417978435754776 , mapper loss : 1.405308723449707
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 16 , Discriminator loss : 0.4106281101703644 , mapper loss : 1.4204736948013306
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 17 , Discriminator loss : 0.4037814736366272 , mapper loss : 1.4361881017684937
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 18 , Discriminator loss : 0.39707812666893005 , mapper loss : 1.4508002996444702
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 19 , Discriminator loss : 0.39058917760849 , mapper loss : 1.464891791343689
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 20 , Discriminator loss : 0.3844730257987976 , mapper loss : 1.4784868955612183
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 21 , Discriminator loss : 0.3785970211029053 , mapper loss : 1.4938349723815918
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 22 , Discriminator loss : 0.37288862466812134 , mapper loss : 1.507934808731079
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 23 , Discriminator loss : 0.3674779236316681 , mapper loss : 1.5224233865737915
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 24 , Discriminator loss : 0.3622035086154938 , mapper loss : 1.5365699529647827
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 25 , Discriminator loss : 0.35716599225997925 , mapper loss : 1.5494930744171143
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 26 , Discriminator loss : 0.35237932205200195 , mapper loss : 1.5632367134094238
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 27 , Discriminator loss : 0.34773752093315125 , mapper loss : 1.577296495437622
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 28 , Discriminator loss : 0.34320810437202454 , mapper loss : 1.5913465023040771
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 29 , Discriminator loss : 0.33888113498687744 , mapper loss : 1.6043421030044556
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 30 , Discriminator loss : 0.3347187042236328 , mapper loss : 1.6169333457946777
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 31 , Discriminator loss : 0.3307913839817047 , mapper loss : 1.6310398578643799
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 32 , Discriminator loss : 0.32692426443099976 , mapper loss : 1.6436412334442139
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 33 , Discriminator loss : 0.3231760859489441 , mapper loss : 1.656345248222351
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 34 , Discriminator loss : 0.31964898109436035 , mapper loss : 1.6693742275238037
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 35 , Discriminator loss : 0.316133052110672 , mapper loss : 1.6822538375854492
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 36 , Discriminator loss : 0.3128853738307953 , mapper loss : 1.6958959102630615
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 37 , Discriminator loss : 0.3095748722553253 , mapper loss : 1.7079180479049683
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 38 , Discriminator loss : 0.30647534132003784 , mapper loss : 1.7196433544158936
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 39 , Discriminator loss : 0.3034648299217224 , mapper loss : 1.7327394485473633
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 40 , Discriminator loss : 0.30053475499153137 , mapper loss : 1.7447789907455444
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 41 , Discriminator loss : 0.2977946996688843 , mapper loss : 1.756899356842041
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 42 , Discriminator loss : 0.29508623480796814 , mapper loss : 1.7681952714920044
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 43 , Discriminator loss : 0.29248321056365967 , mapper loss : 1.7801364660263062
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 44 , Discriminator loss : 0.28993818163871765 , mapper loss : 1.791503667831421
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 45 , Discriminator loss : 0.2874843180179596 , mapper loss : 1.8020943403244019
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 46 , Discriminator loss : 0.2851513922214508 , mapper loss : 1.8143832683563232
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 47 , Discriminator loss : 0.2828338146209717 , mapper loss : 1.8269565105438232
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 48 , Discriminator loss : 0.28051096200942993 , mapper loss : 1.8357089757919312
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 49 , Discriminator loss : 0.2784317135810852 , mapper loss : 1.8470063209533691
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 50 , Discriminator loss : 0.27644142508506775 , mapper loss : 1.8592908382415771
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 51 , Discriminator loss : 0.27438706159591675 , mapper loss : 1.867746353149414
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 52 , Discriminator loss : 0.2724929749965668 , mapper loss : 1.8799494504928589
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 53 , Discriminator loss : 0.2705868184566498 , mapper loss : 1.8901584148406982
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 54 , Discriminator loss : 0.2686895430088043 , mapper loss : 1.9022678136825562
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 55 , Discriminator loss : 0.2669251263141632 , mapper loss : 1.9104493856430054
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 56 , Discriminator loss : 0.2652971148490906 , mapper loss : 1.9222670793533325
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 57 , Discriminator loss : 0.26362812519073486 , mapper loss : 1.9327701330184937
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 58 , Discriminator loss : 0.2619788646697998 , mapper loss : 1.9425557851791382
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 59 , Discriminator loss : 0.2602479159832001 , mapper loss : 1.9518582820892334
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 60 , Discriminator loss : 0.2587380111217499 , mapper loss : 1.9602802991867065
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 61 , Discriminator loss : 0.25735345482826233 , mapper loss : 1.9713560342788696
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 62 , Discriminator loss : 0.25595521926879883 , mapper loss : 1.980858564376831
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 63 , Discriminator loss : 0.254483163356781 , mapper loss : 1.9896687269210815
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 64 , Discriminator loss : 0.2531019449234009 , mapper loss : 2.000236749649048
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 65 , Discriminator loss : 0.2518123388290405 , mapper loss : 2.0087056159973145
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 66 , Discriminator loss : 0.2505039870738983 , mapper loss : 2.017181396484375
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 67 , Discriminator loss : 0.2491784244775772 , mapper loss : 2.026698589324951
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 68 , Discriminator loss : 0.24811036884784698 , mapper loss : 2.0350818634033203
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 69 , Discriminator loss : 0.24689050018787384 , mapper loss : 2.0457520484924316
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 70 , Discriminator loss : 0.24570851027965546 , mapper loss : 2.051820993423462
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 71 , Discriminator loss : 0.24459466338157654 , mapper loss : 2.0604090690612793
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 72 , Discriminator loss : 0.24348805844783783 , mapper loss : 2.0694122314453125
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 73 , Discriminator loss : 0.2425011694431305 , mapper loss : 2.0784125328063965
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 74 , Discriminator loss : 0.2414323389530182 , mapper loss : 2.0865890979766846
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 75 , Discriminator loss : 0.2403213083744049 , mapper loss : 2.095599412918091
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 76 , Discriminator loss : 0.2394321858882904 , mapper loss : 2.1038942337036133
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 77 , Discriminator loss : 0.23848624527454376 , mapper loss : 2.11163592338562
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 78 , Discriminator loss : 0.23751194775104523 , mapper loss : 2.1207895278930664
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 79 , Discriminator loss : 0.23659498989582062 , mapper loss : 2.126430034637451
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 80 , Discriminator loss : 0.23569810390472412 , mapper loss : 2.1343650817871094
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 81 , Discriminator loss : 0.23494137823581696 , mapper loss : 2.1441502571105957
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 82 , Discriminator loss : 0.2340507209300995 , mapper loss : 2.150646448135376
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 83 , Discriminator loss : 0.23319877684116364 , mapper loss : 2.1571874618530273
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 84 , Discriminator loss : 0.23241187632083893 , mapper loss : 2.164358139038086
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 85 , Discriminator loss : 0.2315903902053833 , mapper loss : 2.1729817390441895
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 86 , Discriminator loss : 0.23087550699710846 , mapper loss : 2.180955171585083
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 87 , Discriminator loss : 0.2301373928785324 , mapper loss : 2.1897242069244385
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 88 , Discriminator loss : 0.2294260859489441 , mapper loss : 2.197643280029297
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 89 , Discriminator loss : 0.22879858314990997 , mapper loss : 2.203380584716797
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 90 , Discriminator loss : 0.2280067503452301 , mapper loss : 2.209336280822754
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 91 , Discriminator loss : 0.22723539173603058 , mapper loss : 2.216761350631714
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 92 , Discriminator loss : 0.22669899463653564 , mapper loss : 2.223062038421631
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 93 , Discriminator loss : 0.22599534690380096 , mapper loss : 2.2283546924591064
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 94 , Discriminator loss : 0.2253655046224594 , mapper loss : 2.236088752746582
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 95 , Discriminator loss : 0.22486194968223572 , mapper loss : 2.2431061267852783
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 96 , Discriminator loss : 0.2241942286491394 , mapper loss : 2.250335931777954
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 97 , Discriminator loss : 0.2235611230134964 , mapper loss : 2.258120059967041
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 98 , Discriminator loss : 0.22295351326465607 , mapper loss : 2.2637999057769775
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 99 , Discriminator loss : 0.2223801463842392 , mapper loss : 2.27036190032959
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 100 , Discriminator loss : 0.22184249758720398 , mapper loss : 2.2771549224853516
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 101 , Discriminator loss : 0.2212538868188858 , mapper loss : 2.28254771232605
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 102 , Discriminator loss : 0.22069409489631653 , mapper loss : 2.288891553878784
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 103 , Discriminator loss : 0.22027967870235443 , mapper loss : 2.2951691150665283
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 104 , Discriminator loss : 0.21971870958805084 , mapper loss : 2.3017354011535645
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 105 , Discriminator loss : 0.219227597117424 , mapper loss : 2.3087198734283447
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 106 , Discriminator loss : 0.21864718198776245 , mapper loss : 2.312262535095215
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 107 , Discriminator loss : 0.21827907860279083 , mapper loss : 2.3192074298858643
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 108 , Discriminator loss : 0.21784675121307373 , mapper loss : 2.3252246379852295
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 109 , Discriminator loss : 0.21731358766555786 , mapper loss : 2.3317320346832275
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 110 , Discriminator loss : 0.21688327193260193 , mapper loss : 2.338146209716797
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 111 , Discriminator loss : 0.21643082797527313 , mapper loss : 2.3441576957702637
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 112 , Discriminator loss : 0.21599054336547852 , mapper loss : 2.347327709197998
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 113 , Discriminator loss : 0.21555273234844208 , mapper loss : 2.352325677871704
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 114 , Discriminator loss : 0.21518689393997192 , mapper loss : 2.360872745513916
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 115 , Discriminator loss : 0.21482765674591064 , mapper loss : 2.3649020195007324
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 116 , Discriminator loss : 0.2144392728805542 , mapper loss : 2.3703668117523193
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 117 , Discriminator loss : 0.2139148712158203 , mapper loss : 2.376744508743286
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 118 , Discriminator loss : 0.21366359293460846 , mapper loss : 2.380852222442627
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 119 , Discriminator loss : 0.21314139664173126 , mapper loss : 2.388761281967163
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 120 , Discriminator loss : 0.21283499896526337 , mapper loss : 2.39261794090271
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 121 , Discriminator loss : 0.21243155002593994 , mapper loss : 2.39662504196167
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 122 , Discriminator loss : 0.21197989583015442 , mapper loss : 2.4032819271087646
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 123 , Discriminator loss : 0.21177560091018677 , mapper loss : 2.4073400497436523
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 124 , Discriminator loss : 0.21130722761154175 , mapper loss : 2.4131357669830322
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 125 , Discriminator loss : 0.21097807586193085 , mapper loss : 2.417374849319458
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 126 , Discriminator loss : 0.21071456372737885 , mapper loss : 2.424105644226074
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 127 , Discriminator loss : 0.21034707129001617 , mapper loss : 2.427281618118286
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 128 , Discriminator loss : 0.21010452508926392 , mapper loss : 2.4321248531341553
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 129 , Discriminator loss : 0.20963725447654724 , mapper loss : 2.4377009868621826
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 130 , Discriminator loss : 0.2094372808933258 , mapper loss : 2.442147731781006
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 131 , Discriminator loss : 0.20899933576583862 , mapper loss : 2.445314407348633
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 132 , Discriminator loss : 0.20876440405845642 , mapper loss : 2.4527134895324707
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 133 , Discriminator loss : 0.20860838890075684 , mapper loss : 2.4572091102600098
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 134 , Discriminator loss : 0.20814427733421326 , mapper loss : 2.462150812149048
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 135 , Discriminator loss : 0.20793472230434418 , mapper loss : 2.4673283100128174
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 136 , Discriminator loss : 0.20762324333190918 , mapper loss : 2.470716714859009
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 137 , Discriminator loss : 0.2073550671339035 , mapper loss : 2.4750783443450928
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 138 , Discriminator loss : 0.2070682793855667 , mapper loss : 2.480785846710205
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 139 , Discriminator loss : 0.20679929852485657 , mapper loss : 2.483393430709839
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 140 , Discriminator loss : 0.2065151184797287 , mapper loss : 2.488056182861328
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 141 , Discriminator loss : 0.20628933608531952 , mapper loss : 2.493894338607788
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 142 , Discriminator loss : 0.20596249401569366 , mapper loss : 2.497375011444092
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 143 , Discriminator loss : 0.2057710438966751 , mapper loss : 2.500408887863159
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 144 , Discriminator loss : 0.2055358588695526 , mapper loss : 2.506014585494995
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 145 , Discriminator loss : 0.20527425408363342 , mapper loss : 2.5104610919952393
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 146 , Discriminator loss : 0.2049568146467209 , mapper loss : 2.5137546062469482
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 147 , Discriminator loss : 0.20465101301670074 , mapper loss : 2.517540216445923
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 148 , Discriminator loss : 0.20456139743328094 , mapper loss : 2.5232036113739014
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 149 , Discriminator loss : 0.20434406399726868 , mapper loss : 2.5268633365631104
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch : 150 , Discriminator loss : 0.20407429337501526 , mapper loss : 2.5299196243286133
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
import torch

def procrustes_align(X, Y):
    """Core Procrustes alignment implementation"""
    # Center the embeddings
    X_centered = X - X.mean(0)
    Y_centered = Y - Y.mean(0)

    # SVD decomposition
    U, S, Vt = torch.svd(Y_centered.T @ X_centered)
    W_ortho = U @ Vt.T

    return W_ortho

def batch_csls_sim(X, Y, k=10, batch_size=1024):
    """Memory-efficient Cross-Domain Similarity Local Scaling
    Computes similarity matrix in batches to avoid memory issues"""
    device = X.device
    n = X.shape[0]
    m = Y.shape[0]

    r_y = torch.zeros(m, device=device)
    for i in range(0, m, batch_size):
        end = min(i + batch_size, m)
        batch_Y = Y[i:end]
        sim_batch = batch_Y @ Y.T
        r_y[i:end] = torch.topk(sim_batch, min(k, m)).values.mean(1)

    indices = []
    for i in range(0, n, batch_size):
        end = min(i + batch_size, n)
        batch_X = X[i:end]

        sim_batch = batch_X @ Y.T

        r_x_batch = torch.topk(sim_batch, min(k, m)).values.mean(1)

        csls_batch = 2 * sim_batch - r_x_batch.unsqueeze(1) - r_y.unsqueeze(0)

        batch_indices = csls_batch.argmax(dim=1)
        indices.append(batch_indices)

    return torch.cat(indices)

def align_embeddings(en_emb, hi_emb,W ,  num_iterations=5, k=10, batch_size=1024 ):
    """Align source embeddings (en_emb) to target space (hi_emb)"""
    # Initialize transformation matrix
    d = en_emb.shape[1]


    for i in range(num_iterations):
        mapped_en = en_emb @ W

        nn_indices = batch_csls_sim(mapped_en, hi_emb, k=k, batch_size=batch_size)

        W_new = procrustes_align(en_emb, hi_emb[nn_indices])


        W = W_new



    return W

# Example usage:
W_new = align_embeddings(en_emb, hi_emb,W ,  num_iterations=5 )
mapped_en = en_emb @ W_new
# Out:
# Completed iteration 5/5

# %%
# Example: Translate a single English word
word = "house"
translations = predict_hindi_translation(word, en_words, en_emb, hi_words, hi_emb, W, k=5)

print(f"Translations for '{word}':")
for i, (hi_word, score) in enumerate(translations):
    print(f"{i+1}. {hi_word} (confidence: {score:.4f})")

# If you want to run the interactive app
# create_translation_app(en_words, en_emb, hi_words, hi_emb, W)
# Out:
# Translations for 'house':
# 1. पहचानता (confidence: 4.1560)
# 2. इष्ट (confidence: 4.1004)
# 3. मनाया (confidence: 4.0103)
# 4. 1847 (confidence: 3.9866)
# 5. दिष्ट (confidence: 3.9625)
